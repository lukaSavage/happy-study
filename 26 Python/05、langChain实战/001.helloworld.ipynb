# %%
a = 23
b= 434
print(f'测试一下 {a + b}')
# Out:
# 测试一下 457

# %%
# 调用对话模型
from langchain_openai import ChatOpenAI

chat = ChatOpenAI(model="gpt-4o", temperature=0)
response = chat.predict("说一句中文")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 调用对话模型
# ----> 2 from langchain_openai import ChatOpenAI
#       4 chat = ChatOpenAI(model="gpt-4o", temperature=0)
#       5 response = chat.predict("说一句中文")
#
# ModuleNotFoundError: No module named 'langchain_openai'

# %% [markdown]
# # fwioe
# ## 记否文痞服务

# %%
import sys
print(sys.executable)
# Out:
# e:\happy-study\26 Python\04、uv实战\my-first-project\.venv\Scripts\python.exe
